# %% [markdown]
# <a href="https://colab.research.google.com/github/MonkeyWrenchGang/PythonBootcamp/blob/main/day_5/5_4_Restaurants_in_NYC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NYC Restaurant Inspections
#
#
# ---
#
# Today's data comes from [New York City Restaurant Inspection Results](https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/rs6k-p7g6) This dataset provides restaurant inspections, violations, grades and adjudication information.
#
# ## What are we going to do?
#
# 1. import the data
# 2. convert strings to dates
# 3. clean up column names
# 4. ask some questions of the data
#   - how many resturants by boro?
#   - what is the relationship between grade and score?
#   - how many violations contain the word smoking
#   - help former govenor cuomo and his brother find a pizza resturant.

# %%
# typical packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# mapping package
import folium

# %%
# CSV File's URL
nyc_url = 'https://raw.githubusercontent.com/MonkeyWrenchGang/PythonBootcamp/main/day_5/data/2020_New_York_City_Restaurant_Inspections.csv'

# Read CSV data into a pandas DataFrame
nyc = pd.read_csv(nyc_url)
nyc.head()
# Out:
# <ipython-input-2-64ef0cab7e3a>:5: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   nyc = pd.read_csv(nyc_url)
#       CAMIS                 DBA       BORO BUILDING             STREET  \
# 0  50053139    BASIL BRICK OVEN     Queens     2817       ASTORIA BLVD
# 1  50087123             POPEYES      Bronx     4399  WHITE PLAINS ROAD
# 2  41296533  PABLO'S RESTAURANT   Brooklyn       43      NEWKIRK PLAZA
# 3  50092023         GO GO CURRY  Manhattan       12        JOHN STREET
# 4  50014229   AINSWORTH MIDTOWN  Manhattan       45   EAST   33 STREET
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11102.0  7182041205             Italian      01/02/2020
# 1  10466.0  7186531100             Chicken      01/02/2020
# 2  11226.0  7184217603            American      01/02/2020
# 3  10038.0  2124065555            Japanese      01/02/2020
# 4  10016.0  2122011228            American      01/02/2020
#
#                                             ACTION  ... RECORD DATE  \
# 0  Violations were cited in the following area(s).  ...  07/06/2020
# 1  Violations were cited in the following area(s).  ...  07/06/2020
# 2  Violations were cited in the following area(s).  ...  07/06/2020
# 3  Violations were cited in the following area(s).  ...  07/06/2020
# 4  Violations were cited in the following area(s).  ...  07/06/2020
#
#                          INSPECTION TYPE   Latitude  Longitude  \
# 0  Cycle Inspection / Initial Inspection  40.770645 -73.920227
# 1  Cycle Inspection / Initial Inspection  40.898268 -73.854449
# 2       Cycle Inspection / Re-inspection  40.634729 -73.962739
# 3  Cycle Inspection / Initial Inspection  40.709997 -74.009100
# 4  Cycle Inspection / Initial Inspection  40.746888 -73.982944
#
#   Community Board Council District Census Tract        BIN           BBL   NTA
# 0           401.0             22.0       6900.0  4017403.0  4.008390e+09  QN71
# 1           212.0             11.0      41800.0  2069778.0  2.050420e+09  BX62
# 2           314.0             40.0      52000.0  3121197.0  3.052360e+09  BK42
# 3           101.0              1.0       1502.0  1001103.0  1.000650e+09  MN25
# 4           105.0              2.0       7400.0  1080794.0  1.008638e+09  MN17
#
# [5 rows x 26 columns]

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32998 entries, 0 to 32997
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CAMIS                  32998 non-null  int64
#  1   DBA                    32998 non-null  object
#  2   BORO                   32998 non-null  object
#  3   BUILDING               32917 non-null  object
#  4   STREET                 32988 non-null  object
#  5   ZIPCODE                32573 non-null  float64
#  6   PHONE                  32997 non-null  object
#  7   CUISINE DESCRIPTION    32998 non-null  object
#  8   INSPECTION DATE        32998 non-null  object
#  9   ACTION                 32998 non-null  object
#  10  VIOLATION CODE         32839 non-null  object
#  11  VIOLATION DESCRIPTION  32618 non-null  object
#  12  CRITICAL FLAG          32618 non-null  object
#  13  SCORE                  31795 non-null  float64
#  14  GRADE                  17723 non-null  object
#  15  GRADE DATE             15738 non-null  object
#  16  RECORD DATE            32998 non-null  object
#  17  INSPECTION TYPE        32998 non-null  object
#  18  Latitude               32903 non-null  float64
#  19  Longitude              32903 non-null  float64
#  20  Community Board        32488 non-null  float64
#  21  Council District       32488 non-null  float64
#  22  Census Tract           32488 non-null  float64
#  23  BIN                    32364 non-null  float64
#  24  BBL                    32903 non-null  float64
#  25  NTA                    32488 non-null  object
# dtypes: float64(9), int64(1), object(16)
# memory usage: 6.5+ MB

# %% [markdown]
# ## Convert inspection date

# %%
nyc['INSPECTION DATE'] = pd.to_datetime(nyc['INSPECTION DATE'] )
nyc.head()
# Out:
#       CAMIS                 DBA       BORO BUILDING             STREET  \
# 0  50053139    BASIL BRICK OVEN     Queens     2817       ASTORIA BLVD
# 1  50087123             POPEYES      Bronx     4399  WHITE PLAINS ROAD
# 2  41296533  PABLO'S RESTAURANT   Brooklyn       43      NEWKIRK PLAZA
# 3  50092023         GO GO CURRY  Manhattan       12        JOHN STREET
# 4  50014229   AINSWORTH MIDTOWN  Manhattan       45   EAST   33 STREET
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11102.0  7182041205             Italian      2020-01-02
# 1  10466.0  7186531100             Chicken      2020-01-02
# 2  11226.0  7184217603            American      2020-01-02
# 3  10038.0  2124065555            Japanese      2020-01-02
# 4  10016.0  2122011228            American      2020-01-02
#
#                                             ACTION  ... RECORD DATE  \
# 0  Violations were cited in the following area(s).  ...  07/06/2020
# 1  Violations were cited in the following area(s).  ...  07/06/2020
# 2  Violations were cited in the following area(s).  ...  07/06/2020
# 3  Violations were cited in the following area(s).  ...  07/06/2020
# 4  Violations were cited in the following area(s).  ...  07/06/2020
#
#                          INSPECTION TYPE   Latitude  Longitude  \
# 0  Cycle Inspection / Initial Inspection  40.770645 -73.920227
# 1  Cycle Inspection / Initial Inspection  40.898268 -73.854449
# 2       Cycle Inspection / Re-inspection  40.634729 -73.962739
# 3  Cycle Inspection / Initial Inspection  40.709997 -74.009100
# 4  Cycle Inspection / Initial Inspection  40.746888 -73.982944
#
#   Community Board Council District Census Tract        BIN           BBL   NTA
# 0           401.0             22.0       6900.0  4017403.0  4.008390e+09  QN71
# 1           212.0             11.0      41800.0  2069778.0  2.050420e+09  BX62
# 2           314.0             40.0      52000.0  3121197.0  3.052360e+09  BK42
# 3           101.0              1.0       1502.0  1001103.0  1.000650e+09  MN25
# 4           105.0              2.0       7400.0  1080794.0  1.008638e+09  MN17
#
# [5 rows x 26 columns]

# %%
nyc['CUISINE DESCRIPTION'].value_counts()
# Out:
# American             6305
# Chinese              3801
# Café/Coffee/Tea      1642
# Mexican              1566
# Pizza                1451
#                      ...
# Iranian                 5
# Fruits/Vegetables       4
# Czech                   4
# Portuguese              3
# Basque                  2
# Name: CUISINE DESCRIPTION, Length: 82, dtype: int64

# %%
nyc.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA'],
#       dtype='object')

# %% [markdown]
# ## Clean up Column Names
#
#
# ---

# %%
nyc.columns = nyc.columns.str.lower()
nyc.columns = nyc.columns.str.replace(' ','_')
nyc.columns
# Out:
# Index(['camis', 'dba', 'boro', 'building', 'street', 'zipcode', 'phone',
#        'cuisine_description', 'inspection_date', 'action', 'violation_code',
#        'violation_description', 'critical_flag', 'score', 'grade',
#        'grade_date', 'record_date', 'inspection_type', 'latitude', 'longitude',
#        'community_board', 'council_district', 'census_tract', 'bin', 'bbl',
#        'nta'],
#       dtype='object')

# %%
# Out:
#                             dba       boro   latitude  longitude  score grade
# 9                   PRIMA PIZZA      Bronx  40.890903 -73.849495   11.0     A
# 44        99 CENT EXPRESS PIZZA  Manhattan  40.758087 -73.989720   11.0     A
# 57     FAMOUS FAMIGLIA PIZZERIA  Manhattan  40.787876 -73.953693   43.0     Z
# 82            MAMA'S PIZZA CAFE  Manhattan  40.758752 -73.988695   13.0     A
# 126                ITALIA PIZZA   Brooklyn  40.605048 -73.978968   12.0     A
# ...                         ...        ...        ...        ...    ...   ...
# 32929               LAYLA JONES   Brooklyn  40.686652 -73.993845   13.0     A
# 32960       SINGAS FAMOUS PIZZA     Queens  40.751584 -73.870640   23.0     N
# 32961       BROOKLYN PIZZA CREW   Brooklyn  40.672761 -73.950240    7.0     A
# 32969       SINGAS FAMOUS PIZZA     Queens  40.751584 -73.870640   23.0     N
# 32980               J & R PIZZA   Brooklyn  40.610355 -73.954386   12.0     A
#
# [805 rows x 6 columns]

# %% [markdown]
# # Asking Questions
#
# 1. how many boros are their in NYC?

# %%
nyc['boro'].value_counts()
# Out:
# Manhattan        13254
# Brooklyn          8210
# Queens            7802
# Bronx             2672
# Staten Island     1048
# 0                   12
# Name: boro, dtype: int64

# %% [markdown]
# 2. make a histogram of `score`

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=nyc,
            x='score',
             #hue="grade",
             bins=20,
             color='steelblue')
plt.title('Histogram of Score')
plt.xlabel('GRADE')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Make a Boxplot of Scores

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=nyc,
            x='grade',
            y='score')
plt.title('Boxplit of score by grade')
plt.xlabel('GRADE')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 3. what is the relationship between score and grade? make a barchart of the mean score by grade. make a 2nd barchart of the count by grade.
#
# Restaurants with a score between 0 and 13 points earn an A, those with 14 to 27 points receive a B and those with 28
# or more a C.

# %%
nyc.groupby('grade')[['score']].mean()
# Out:
#            score
# grade
# A      10.132344
# B      20.766082
# C      43.132716
# N      33.393145
# P       8.722222
# Z      28.098327

# %%
res1 = nyc.groupby('grade')[['score']].mean().reset_index()
res1
# Out:
#   grade      score
# 0     A  10.132344
# 1     B  20.766082
# 2     C  43.132716
# 3     N  33.393145
# 4     P   8.722222
# 5     Z  28.098327

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=res1,
            x='grade',
            y='score',
             color='steelblue')
plt.title('NYC Score to Grade Means')
plt.xlabel('GRADE')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %%
res1 = nyc.groupby('grade').agg({'score':['mean','count']}).reset_index()
res1
# Out:
#   grade      score
#               mean  count
# 0     A  10.132344  12067
# 1     B  20.766082    855
# 2     C  43.132716    324
# 3     N  33.393145   1984
# 4     P   8.722222     36
# 5     Z  28.098327   2451

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=res1,
            x='grade',
            y=('score','count'),
             color='steelblue')
plt.title('NYC Score to Grade Count')
plt.xlabel('GRADE')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 4. how many violation descriptions contain the word "smoking", select dba, 'boro', inspection_date, violation_description

# %%
filter_mask = (nyc["violation_description"].str.contains('smoking')) & \
              (nyc["violation_description"].notna())

nyc[filter_mask][["dba", 'boro',"inspection_date", "violation_description"]]
# Out:
#                                    dba           boro inspection_date  \
# 730                           LADYBIRD      Manhattan      2020-01-03
# 4000                  CAFE - BAR LAIKA       Brooklyn      2020-01-10
# 4137            JIN JIN HONG KONG CAFE       Brooklyn      2020-01-13
# 4190                       KUNG FU TEA         Queens      2020-01-13
# 5062                     JAPAN VILLAGE       Brooklyn      2020-01-14
# 7540                    KINGS PASTRAMI       Brooklyn      2020-01-18
# 8425                     NEW CHINA III         Queens      2020-01-22
# 9464                          NOWADAYS         Queens      2020-01-23
# 11196                     ZAO MEN QIAN         Queens      2020-01-28
# 12243                BLACK SEED BAGELS      Manhattan      2020-01-30
# 13756                    TENDER GREENS      Manhattan      2020-02-03
# 18508                     EAST PACIFIC  Staten Island      2020-02-12
# 19566                      FISH CHEEKS      Manhattan      2020-02-14
# 19900                  HOTEL CHANTELLE      Manhattan      2020-02-15
# 20882   LUCKY HOUSE CHINESE RESTAURANT          Bronx      2020-02-19
# 25268                    TULCINGO CAFE          Bronx      2020-02-27
# 26559                           SUBWAY      Manhattan      2020-03-03
# 27039                 BROTHERS SEAFOOD          Bronx      2020-03-03
# 27771               QDOBA MEXICAN EATS  Staten Island      2020-03-04
# 31161  KAM'S GARDEN CHINESE RESTAURANT         Queens      2020-03-11
# 32019                         ANGELINA      Manhattan      2020-03-12
# 32118                          STOCKED       Brooklyn      2020-03-13
#
#                                    violation_description
# 730    Food worker does not wash hands thoroughly aft...
# 4000   Food worker does not wash hands thoroughly aft...
# 4137   Food worker does not wash hands thoroughly aft...
# 4190   Food worker does not wash hands thoroughly aft...
# 5062   Food worker does not wash hands thoroughly aft...
# 7540   Food worker does not wash hands thoroughly aft...
# 8425   Food worker does not wash hands thoroughly aft...
# 9464   Food worker does not wash hands thoroughly aft...
# 11196  Food worker does not wash hands thoroughly aft...
# 12243  Food worker does not wash hands thoroughly aft...
# 13756  Food worker does not wash hands thoroughly aft...
# 18508  Food worker does not wash hands thoroughly aft...
# 19566  Food worker does not wash hands thoroughly aft...
# 19900  Food worker does not wash hands thoroughly aft...
# 20882  Food worker does not wash hands thoroughly aft...
# 25268  Food worker does not wash hands thoroughly aft...
# 26559  Food worker does not wash hands thoroughly aft...
# 27039  Food worker does not wash hands thoroughly aft...
# 27771  Food worker does not wash hands thoroughly aft...
# 31161  Food worker does not wash hands thoroughly aft...
# 32019  Food worker does not wash hands thoroughly aft...
# 32118  Food worker does not wash hands thoroughly aft...

# %% [markdown]
# ## Govenor Cuomo & his Brother
#
# The former Governor would like to take his brother out for a nice slice of pizza, where are all the pizza restaurants in NYC with a grade of A?

# %%
# Filter rows with specific conditions
nyc_insp = nyc.query("cuisine_description == 'Pizza' \
                      and latitude.notna() and grade.notna()\
                      and grade == 'A'")[
    ["dba", "boro", "latitude", "longitude","score","grade"]]
nyc_insp
# Out:
#                          dba       boro   latitude  longitude  score grade
# 9                PRIMA PIZZA      Bronx  40.890903 -73.849495   11.0     A
# 44     99 CENT EXPRESS PIZZA  Manhattan  40.758087 -73.989720   11.0     A
# 82         MAMA'S PIZZA CAFE  Manhattan  40.758752 -73.988695   13.0     A
# 126             ITALIA PIZZA   Brooklyn  40.605048 -73.978968   12.0     A
# 144              PRIMA PIZZA      Bronx  40.890903 -73.849495   11.0     A
# ...                      ...        ...        ...        ...    ...   ...
# 32859            LAYLA JONES   Brooklyn  40.686652 -73.993845   13.0     A
# 32882            LAYLA JONES   Brooklyn  40.686652 -73.993845   13.0     A
# 32929            LAYLA JONES   Brooklyn  40.686652 -73.993845   13.0     A
# 32961    BROOKLYN PIZZA CREW   Brooklyn  40.672761 -73.950240    7.0     A
# 32980            J & R PIZZA   Brooklyn  40.610355 -73.954386   12.0     A
#
# [529 rows x 6 columns]

# %% [markdown]
# ## Wow there is a lot of Duplicates
#
# let's deal with them!
#
# The `.drop_duplicates()` function in pandas is used to remove duplicate values from a DataFrame or Series. It helps in identifying and eliminating duplicate records based on specified columns or the entire dataset.
#
# Here's a brief introduction to the `.drop_duplicates()` function:
#
# Syntax:
# ```python
# DataFrame.drop_duplicates(subset=None, keep='first', inplace=False)
# ```
#
# Parameters:
#
# - `subset` (optional): Specifies the column(s) to consider for identifying duplicates. By default, it is set to None, which considers all columns.
# - `keep` (optional): Determines which duplicate values to keep. It can take the following values:
#   - first: Keep the first occurrence of each set of duplicates.
#   - last: Keep the last occurrence of each set of duplicates.
#   - False: Remove all occurrences of duplicates.
# - `inplace` (optional): Specifies whether to modify the DataFrame in-place or return a new DataFrame with duplicates removed. By default, it is set to False, which returns a new DataFrame.

# %%
# Filter rows with specific conditions
nyc_insp = nyc.query("cuisine_description == 'Pizza' \
                      and latitude.notna() and grade.notna()\
                      and grade == 'A'")[
    ["dba", "boro", "latitude", "longitude","score","grade"]].drop_duplicates().reset_index()
nyc_insp
# Out:
#      index                       dba       boro   latitude  longitude  score  \
# 0        9               PRIMA PIZZA      Bronx  40.890903 -73.849495   11.0
# 1       44     99 CENT EXPRESS PIZZA  Manhattan  40.758087 -73.989720   11.0
# 2       82         MAMA'S PIZZA CAFE  Manhattan  40.758752 -73.988695   13.0
# 3      126              ITALIA PIZZA   Brooklyn  40.605048 -73.978968   12.0
# 4      822              2 BROS PIZZA  Manhattan  40.804765 -73.938340    4.0
# ..     ...                       ...        ...        ...        ...    ...
# 235  32584                  DOMINO'S     Queens  40.765350 -73.817030    7.0
# 236  32689       BROOKLYN PIZZA CREW   Brooklyn  40.672761 -73.950240    7.0
# 237  32707            LITTLE CAESARS   Brooklyn  40.662633 -73.920320    4.0
# 238  32769  CALIFORNIA PIZZA KITCHEN     Queens  40.709259 -73.870056   12.0
# 239  32859               LAYLA JONES   Brooklyn  40.686652 -73.993845   13.0
#
#     grade
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A
# ..    ...
# 235     A
# 236     A
# 237     A
# 238     A
# 239     A
#
# [240 rows x 7 columns]

# %% [markdown]
# ## Let's Map Them!

# %%
# Create a map centered on a specific location in this case NYC
m = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# Add markers to the map based on the latitude and longitude coordinates
for _, row in nyc_insp.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['dba']
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a55b6fd230a6f2bf7563e3a737f17ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a55b6fd230a6f2bf7563e3a737f17ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a55b6fd230a6f2bf7563e3a737f17ed = L.map(
#                 &quot;map_7a55b6fd230a6f2bf7563e3a737f17ed&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_489e21adfed36acc8ce5b32856b5051a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a55b6fd230a6f2bf7563e3a737f17ed);
#
#
#             var marker_b582b51a4d5ade0eae390f3ec959f97b = L.marker(
#                 [40.890903489495, -73.849495317655],
#                 {}
#             ).addTo(map_7a55b6fd230a6f2bf7563e3a737f17ed);
#
#
#         var popup_aba3693ebec187cda96ab544f30ef755 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5accfe53eee772f1edad09d3474eb7e1 = $(`&lt;div id=&quot;html_5accfe53eee772f1edad09d3474eb7e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PRIMA PIZZA&lt;/div&gt;`)[0];
#                 popup_aba3693ebec187cda96ab544f30ef755.setContent(html_5accfe53eee772f1edad09d3474eb7e1);
#
#
#
#         marker_b582b51a4d5ade0eae390f3ec959f97b.bindPopup(popup_aba3693ebec187cda96ab544f30ef755)
#         ;
#
#
#
#
#             var marker_0f9c17a1ff888a7e797e38f76f053580 = L.marker(
#                 [40.758087468626, -73.98971981313],
#                 {}
#             ).addTo(map_7a55b6fd230a6f2bf7563e3a737f17ed);
#
#
#         var popup_5f7b97f3b3c94f9cb6c24b03acf97e67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4dbf588d862c93da380dc96b81bd987 = $(`&lt;div id=&quot;html_e4dbf588d862c93da380dc96b81bd987&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;99 CENT EXPRESS PIZZA&lt;/div&gt;`)[0];
#                 popup_5f7b97f3b3c94f9cb6c24b03acf97e67.setContent(html_e4dbf588d862c93da380dc96b81bd987);
#
#
#
#         marker_0f9c17a1ff888a7e797e38f76f053580.bindPopup(popup_5f7b97f3b3c94f9cb6c24b03acf97e67)
#         ;
#
#
#
#
#             var marker_36c2218c312c6c2b8cecc601e1e12d56 = L.marker(
#                 [40.758751603856, -73.988694568973],
#                 {}
#             ).addTo(map_7a55b6fd230a6f2bf7563e3a737f17ed);
#
#
#         var popup_19bbb3a4b96ddc2141127650015396f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed44d9039000d2ba770023f533a05e4e = $(`&lt;div id=&quot;html_ed44d9039000d2ba770023f533a05e4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAMA&#x27;S PIZZA CAFE&lt;/div&gt;`)[0];
#                 popup_19bbb3a4b96ddc2141127650015396f8.setContent(html_ed44d9039000d2ba770023f533a05e4e);
#
#
#
#         marker_36c2218c312c6c2b8cecc601e1e12d56.bindPopup(popup_19bbb3a4b96ddc2141127650015396f8)
#         ;
#
#
#
#
#             var marker_3bf273c6ec16203a66ba28f1c28884b2 = L.marker(
#                 [40.605048366708, -73.978968349141],
#                 {}
#             ).addTo(map_7a55b6fd230a6f2bf7563e3a737f17ed);
#
#
#         var popup_6e092d277d72d237a2a1ea971c4edeb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_024325f23deae3c75a31893c0a229549 = $(`&lt;div id=&quot;html_024325f23deae3c75a31893c0a229549&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ITALIA PIZZA&lt;/div&gt;`)[0];
#                 popup_6e092d277d72d237a2a1ea971c4edeb0.setContent(html_024325f23deae3c75a31893c0a229549);
#
#
#
#         marker_3bf273c6ec16203a66ba28f1c28884b2.bindPopup(popup_6e092d277d72d237a2a1ea971c4edeb0)
#         ;
#
#
#
#
#             var marker_1c99146d8127849c40a13960a164754b = L.marker(
#                 [40.804765113984, -73.938340471036],
#                 {}
#             ).addTo(map_7a55b6fd230a6f2bf7563e3a737f17ed);
#
#
#         var popup_69010382a101aa813e779695248f6c9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02cf0604307825d19a3d2ade9565437b = $(`&lt;div id=&quot;html_02cf0604307825d19a3d2ade9565437b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2 BROS PIZZA&lt;/div&gt;`)[0];
#                 popup_69010382a101aa813e779695248f6c9e.setContent(html_02cf0604307825d19a3d2ade9565437b);
#
#
#
#         marker_1c99146d8127849c40a13960a164754b.bindPopup(popup_69010382a101aa813e779695248f6c9e)
#         ;
#
#
#
#
#             var marker_a02a18849ee27e7ef1d0790f3373

# %% [markdown]
# ## The Gov and his Bro
# want to ensure that they avoid B,C grade pizza restuarnts change your query above to filter for B & C then we'll color the results on the map!

# %%
# Filter rows with specific conditions
nyc_insp2 = nyc.query("cuisine_description == 'Pizza' \
                      and latitude.notna() and grade.notna()\
                      and grade == ['B','C']")[
    ["dba", "boro", "latitude", "longitude","score","grade"]].drop_duplicates().reset_index()
nyc_insp2
# Out:
#     index                         dba           boro   latitude  longitude  \
# 0     645               J-II PIZZERIA       Brooklyn  40.617980 -73.960180
# 1    2357      MARTINIELLO'S PIZZERIA         Queens  40.710910 -73.905178
# 2    2361         GOLD GRILL PIZZERIA  Staten Island  40.628936 -74.116757
# 3    3275              LITTLE CAESARS          Bronx  40.824043 -73.873538
# 4    6476                 SAL'S PIZZA          Bronx  40.875165 -73.879493
# 5    7687                  CITY PIZZA      Manhattan  40.759877 -73.991586
# 6    7780  99 CENTS TASTY PIZZA PLACE      Manhattan  40.757912 -73.991442
# 7    8134   LUCY'S PIZZA & RESTAURANT       Brooklyn  40.604229 -73.971701
# 8    9012              NOEL'S PIZZA 2          Bronx  40.862688 -73.902889
# 9   11572               BAKER'S PIZZA      Manhattan  40.729371 -73.981123
# 10  12360             MANGIA PIZZA II         Queens  40.678322 -73.831900
# 11  17546                JOHN'S PIZZA      Manhattan  40.758117 -73.987897
# 12  18133       RICHMOND FAMILY PIZZA  Staten Island  40.600904 -74.092681
# 13  21009                BOSTON PIZZA         Queens  40.759658 -73.920449
# 14  24705                 PIZZA MANNA         Queens  40.694621 -73.751621
#
#     score grade
# 0    17.0     B
# 1    14.0     B
# 2    26.0     B
# 3    17.0     B
# 4    19.0     B
# 5    59.0     C
# 6    26.0     B
# 7    49.0     C
# 8    28.0     C
# 9    24.0     B
# 10   19.0     B
# 11   42.0     C
# 12   22.0     B
# 13   25.0     B
# 14   19.0     B

# %%
import folium

# Create a map centered on a specific location (in this case, NYC)
m = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# Define color mapping for grades
color_mapping = {
    'A': 'green',
    'B': 'orange',
    'C': 'red'
}

# Add markers to the map based on the latitude and longitude coordinates
for _, row in nyc_insp2.iterrows():
    grade = row['grade']
    color = color_mapping.get(grade, 'gray')  # Set default color to gray if grade is not in the mapping
    biz_popup = f"{row['dba']} - score: {row['score']}"
    folium.Marker(
        location=[row['latitude'], row['longitude']],

        popup=biz_popup,
        icon=folium.Icon(color=color)
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f8f0dbdd2a28eac6da9809029a53c49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f8f0dbdd2a28eac6da9809029a53c49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f8f0dbdd2a28eac6da9809029a53c49 = L.map(
#                 &quot;map_2f8f0dbdd2a28eac6da9809029a53c49&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba835d9e5d26012c1fe56bde0a3d65ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f8f0dbdd2a28eac6da9809029a53c49);
#
#
#             var marker_dda2e5c7963abfcde309522aa4ad6451 = L.marker(
#                 [40.617979548804, -73.960179773692],
#                 {}
#             ).addTo(map_2f8f0dbdd2a28eac6da9809029a53c49);
#
#
#             var icon_90a6b3603073752a31a48bb7a55fcc70 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dda2e5c7963abfcde309522aa4ad6451.setIcon(icon_90a6b3603073752a31a48bb7a55fcc70);
#
#
#         var popup_e51576698f65f5a141e50228839a8be7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38774decf130a5e3952fab79e27c6e54 = $(`&lt;div id=&quot;html_38774decf130a5e3952fab79e27c6e54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;J-II PIZZERIA - score: 17.0&lt;/div&gt;`)[0];
#                 popup_e51576698f65f5a141e50228839a8be7.setContent(html_38774decf130a5e3952fab79e27c6e54);
#
#
#
#         marker_dda2e5c7963abfcde309522aa4ad6451.bindPopup(popup_e51576698f65f5a141e50228839a8be7)
#         ;
#
#
#
#
#             var marker_6cfaf5d6ea6d17cf4f17a961dd71af6a = L.marker(
#                 [40.710910142714, -73.9051778102],
#                 {}
#             ).addTo(map_2f8f0dbdd2a28eac6da9809029a53c49);
#
#
#             var icon_7883a159d52f08761f51b5a01de9622b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6cfaf5d6ea6d17cf4f17a961dd71af6a.setIcon(icon_7883a159d52f08761f51b5a01de9622b);
#
#
#         var popup_a7e31c2e7b34690d4946b68413b7111d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3bcc73c63807f13cb91f09535094ac12 = $(`&lt;div id=&quot;html_3bcc73c63807f13cb91f09535094ac12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MARTINIELLO&#x27;S PIZZERIA - score: 14.0&lt;/div&gt;`)[0];
#                 popup_a7e31c2e7b34690d4946b68413b7111d.setContent(html_3bcc73c63807f13cb91f09535094ac12);
#
#
#
#         marker_6cfaf5d6ea6d17cf4f17a961dd71af6a.bindPopup(popup_a7e31c2e7b34690d4946b68413b7111d)
#         ;
#
#
#
#
#             var marker_68b2a22b7609c006217993e429608694 = L.marker(
#                 [40.628936288323, -74.116756828707],
#                 {}
#             ).addTo(map_2f8f0dbdd2a28eac6da9809029a53c49);
#
#
#             var icon_8e14cb5f0aab5e866671c952582f1773 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68b2a22b7609c006217993e429608694.setIcon(icon_8e14cb5f0aab5e866671c952582f1773);
#
#
#         var popup_0148da23e91c68adf88b1f4f30c19e8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10a881dba22728c828546703a7d24414 = $(`&lt;div id=&quot;html_10a881dba22728c828546703a7d24414&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GOLD GRILL PIZZERIA - score: 26.0&lt;/div&gt;`)[0];
#                 popup_0148da23e91c68adf88b1f4f30c19e8e.setContent(html_10a881dba22728c828546703a7d24414);
#
#
#
#         marker_68b2a22b7609c006217993e429608694.bindPopup(popup_0148da23e91c68adf88b1f4f30c19e8e)
#         ;
#
#
#
#
#             var marker_a5ee2779e1940c60047dc0a0bb548f21 = L.marker(
#                 [40.824043287785, -73.873537684618],
#                 {}
#             ).addTo(map_2f8f0dbdd2a28eac6da9809029a53c49);
#
#
#             var icon_b3480d4408d41c7c6a758b0487d41fec = L.A
